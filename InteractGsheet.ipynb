# %%
import pandas as pd
import pygsheet

# %%
def process_OPList(data):
    data['date_AC'] = data['date'].astype(int)
    data['date_AC'] = 19110000 + data['date_AC']
    data['date_AC'] = pd.to_datetime(data['date_AC'],
                                    format='%Y%m%d')
    data['Diagnosis'] = [st.replace('術前診斷:','') for st in data['Diagnosis']]
    data['Procedure'] = [st.replace('手術名稱:','') for st in data['Procedure']]
    data['IOL'] = [st.replace('手術室資訊:','') for st in data['OR info']]
    data['Anes'] = [st.replace('麻醉:','' ) for st in data['Anes']]
    return data.drop(columns=['change','OR info'])

# %%
OP_list = pd.read_csv('OPList.csv')
OP_list_processed = process_OPList(OP_list)
OP_list_date = OP_list_processed.query("date_AC < '2023-05-15'")

for index, row in OP_list.iterrows():
    break
    print(row['MRN'])
    
    break
OP_list_date
# Out:
#        date  time admission  dpt       MRN  name room   VS status emergency
# 0   1120501  1130     OPD -  OPH  30282316   張心亭  B08  翁章旂    已執行         N  \
# 1   1120501  1230     OPD -  OPH  17377423   洪仁道  B08  翁章旂    已執行         N
# 2   1120501  1330     OPD -  OPH  48357842  林張信子  B08  翁章旂    已執行         N
# 3   1120501  1400     OPD -  OPH  24621849   王明發  B08  翁章旂    已執行         N
# 4   1120501  1430     OPD -  OPH  29948376   楊旭平  B08  翁章旂    已執行         N
# 5   1120501  1500     OPD -  OPH  11911470  關林阿女  B08  翁章旂    已執行         N
# 6   1120504  0800     OPD -  OPH  42795142   高淑女  B06  翁章旂    已執行         N
# 7   1120504  0832     OPD -  OPH  13934902   劉鳳嬌  B06  翁章旂    已執行         N
# 8   1120504  1330     OPD -  OPH   7258619   葉江清  B07  翁章旂    已執行         N
# 9   1120508  0830     OPD -  OPH  15081513   王虎生  B10  翁章旂    已執行         N
# 10  1120508  0832     OPD -  OPH  27631670   陳吉雄  B10  翁章旂    已執行         N
# 11  1120508  1202     OPD -  OPH  28684084   莊麗雪  B08  翁章旂    已執行         N
# 12  1120508  1300     OPD -  OPH  49282497   孫興全  B08  翁章旂    已執行         N
# 13  1120508  1303     B088-  OPH  49173402   許玉素  B08  翁章旂    已執行     Y (C)
# 14  1120508  1430     OPD -  OPH  31491051    黃欣  B08  翁章旂    已執行         N
# 15  1120508  1431     OPD -  OPH  36234318   黃素娥  B08  翁章旂    已執行         N
# 16  1120510  2100     B088-  OPH  28052882   陳韋安  _07  翁章旂    已取消         N
# 17  1120511  1401   B088- 8  OPH  37023328   張仁誌  B07  翁章旂    已執行     Y (C)
# 18  1120512  1556     B088-  OPH  49510089   賴世揚  B09  翁章旂    已執行     Y (C)
# 19  1120512  2029   B088-29  OPH  49510896   羅英瑞  B09  翁章旂    已執行     Y (C)
#
#                                             Diagnosis
# 0   CATA OD [全自費!!]                               ...  \
# 1   CATA OD                                       ...
# 2   CATA OD                                       ...
# 3   CATA OD                                       ...
# 4   CATA OS                                       ...
# 5   CATA OD                                       ...
# 6   CATA OS [AAB, ori: 7.0, T:-1~-2]              ...
# 7   CATA OD                                       ...
# 8   CATA OD                                       ...
# 9   CATA OD                                       ...
# 10  CATA OS [0800報到]                              ...
# 11  CATA OD [1130報到]                              ...
# 12  CATA OD                                       ...
# 13  MHRD OD [術前要改Yc]                              ...
# 14  CATA OD                                       ...
# 15  CATA OS                                       ...
# 16  RRD OS[改YC]                                   ...
# 17  RD OS(5/10 AD) [改YC]                          ...
# 18  RRD OS                                        ...
# 19  RRD OS                                        ...
#
#                                      Procedure Anes    date_AC           IOL
# 0    LENSX-PHACO-IOL OD, IVGA, [ICB ori+17.0]    GA 2023-05-01
# 1             PHACO-IOL OD [RAO600C Ori+10.5]    RA 2023-05-01
# 2                 PHACO-IOL OD [ICB Ori+20.0]    RA 2023-05-01
# 3                 PHACO-IOL OD [AAB ori+10.0]    RA 2023-05-01
# 4                  PHACO-IOL OS [ICB Ori+8.5]    RA 2023-05-01
# 5                                PHACO-IOL OD    RA 2023-05-01   AAB F+27.5
# 6                                PHACO-IOL OS    RA 2023-05-04
# 7                     PHACO-IOL+IVIA OD [AAB]    RA 2023-05-04
# 8                                PHACO-IOL OD    RA 2023-05-04
# 9          PHACO-IOL OD [AAB, T:-2, Ori+17.5]    RA 2023-05-08
# 10        PHACO-IOL OS [Aspira Ori+19.5] 備CTR    RA 2023-05-08
# 11                   PHACO-IOL OD [NHI, 度數未定]    RA 2023-05-08
# 12                PHACO-IOL OD AAB [ori+18.0]    RA 2023-05-08
# 13                     VT GAS LASER OD [+SF6]    RA 2023-05-08
# 14                       PHACO-IOL OD (AAB00)    RA 2023-05-08
# 15                         PHACO-IOL OS (NHI)    RA 2023-05-08
# 16                            VT GAS LASER OS    RA 2023-05-10
# 17                        ENCIRCLING SB OS+VT    GA 2023-05-11
# 18                            VT GAS LASER OS    RA 2023-05-12
# 19                            VT GAS LASER OS    RA 2023-05-12
